# %%
from pylib import *
import numpy as np
import pandas as pd

# %%
node_num = 397-1
time_stamps_sim = pd.date_range(start='2018-11-1 00:00:00', end='2019-6-15 23:00:00', freq="6h")
num_file = len(time_stamps_sim)
ice_dep = np.zeros(num_file)
for time in range(num_file):
    file_ind = time+1
    # time_arr[time] = time*6.0*3600
    filename = "./outputs/out2d_"+str(file_ind)+".nc"
    ncfile=ReadNC(filename)
    ice_dep_arr=array(ncfile.iceTracer_1.val) # this variable is on NODE
    ice_dep[time] = ice_dep_arr[0, node_num]

# %%
import matplotlib.pyplot as plt
import matplotlib.tri as tri
from matplotlib import pylab
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib as mpl

mpl.rcParams['text.usetex'] = True
# Set font properties globally
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)

plt.tight_layout()
fig, ax = plt.subplots(figsize = (12.5, 6))
ax.plot(time_stamps_sim, ice_dep/1.01, linewidth = 1.60, label="Ice Simulation",color='blue')
ax.scatter([pd.Timestamp(2019, 1, 16, 0),pd.Timestamp(2019, 3, 20, 0)], [0.950, 0.47], label="Observation",marker='o',color='red', facecolors='none', linewidth=4.25, s=250, zorder=11)

plt.legend(framealpha=0.5)
plt.legend(loc='best')

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')

ax.set_xlim([pd.Timestamp(2018, 11, 1, 0), pd.Timestamp(2019, 6, 20, 0)])
ax.set_ylim([0.0,  2.])

plt.xticks(pd.date_range('2018-11-1 00', '2019-6-20 00', freq='2m'))

ax.set_xlabel(r'Time')
ax.set_ylabel(r'Ice Thickness (m)')

fig.savefig("./upstream_ice_thickness.jpeg", dpi=500)
# Out:
# C:\Users\byy\AppData\Local\Temp\ipykernel_10832\3328807782.py:28: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.xticks(pd.date_range('2018-11-1 00', '2019-6-20 00', freq='2m'))

# %%
node_num = 4263-1
time_stamps_sim = pd.date_range(start='2018-11-1 00:00:00', end='2019-6-15 23:00:00', freq="6h")
num_file = len(time_stamps_sim)
ice_dep = np.zeros(num_file)
for time in range(num_file):
    file_ind = time+1
    # time_arr[time] = time*6.0*3600
    filename = "./outputs/out2d_"+str(file_ind)+".nc"
    ncfile=ReadNC(filename)
    ice_dep_arr=array(ncfile.iceTracer_1.val) # this variable is on NODE
    ice_dep[time] = ice_dep_arr[0, node_num]

# %%
import matplotlib.pyplot as plt
import matplotlib.tri as tri
from matplotlib import pylab
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib as mpl

mpl.rcParams['text.usetex'] = True
# Set font properties globally
plt.rcParams['font.family'] = "Times New Roman"
# Set font properties globally
plt.rcParams['font.size'] = 20
plt.rcParams['axes.unicode_minus'] = False
plt.figure(dpi=600)

plt.tight_layout()
fig, ax = plt.subplots(figsize = (12.5, 6))
ax.plot(time_stamps_sim, ice_dep/1.05, linewidth = 1.60, label="Ice Simulation",color='blue')
ax.scatter([pd.Timestamp(2019, 2, 10, 0)], [0.69], label="Observation",marker='o',color='red', facecolors='none', linewidth=4.25, s=250, zorder=11)

plt.legend(framealpha=0.5)
plt.legend(loc='best')

plt.grid(linestyle = 'dashed', linewidth = 0.5, color='#C0C0C0')

ax.set_xlim([pd.Timestamp(2018, 11, 1, 0), pd.Timestamp(2019, 6, 20, 0)])
ax.set_ylim([0.0,  2.])

plt.xticks(pd.date_range('2018-11-1 00', '2019-6-20 00', freq='2m'))

ax.set_xlabel(r'Time')
ax.set_ylabel(r'Ice Thickness (m)')

fig.savefig("./downstream_ice_thickness.jpeg", dpi=500)
# Out:
# C:\Users\byy\AppData\Local\Temp\ipykernel_10832\2306454259.py:28: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   plt.xticks(pd.date_range('2018-11-1 00', '2019-6-20 00', freq='2m'))
